# %% [markdown]
# # Basic examples
#
# **Make sure you load the API keys for cloud providers!**

# %% [markdown]
# **You can set your environment keys yourself or use a script. Please note that since keys are private, they are not included in the repository.**

# %%
# setting the environment variables, the keys
import sys
import os

sys.path.insert(0, os.path.abspath('..'))

from config import set_environment
# for the keys - as explained early in chapter 2
set_environment()

# %% [markdown]
# You can use the same interface to work with different LLMs.

# %%
from langchain_openai import OpenAI
from langchain_google_genai import GoogleGenerativeAI

# initialize Gemini
gemini_pro = GoogleGenerativeAI(model="gemini-2.0-flash")

# or: initialize OpenAI model
# openai_llm = OpenAI()

# Both can be used with the same interface
# response = openai_llm.invoke("Tell me a joke about light bulbs!")
response = gemini_pro.invoke("Tell me a joke about light bulbs!")
print(response)
# Out:
# Why did the light bulb go to school?
#
# Because he wanted to be brighter!

# %% [markdown]
# For testing, there's the FakeListLLM

# %%
from langchain_community.llms import FakeListLLM

# Create a fake LLM that always returns the same responses
fake_llm = FakeListLLM(responses=["Hello"])

result = fake_llm.invoke("Any input will return Hello")
print(result)  # Output: Hello
# Out:
# Hello

# %% [markdown]
# The default interface to work with LLMs if the Chat interface though.

# %%
from langchain_anthropic import ChatAnthropic
# or: from langchain_openai.chat_models import ChatOpenAI
from langchain_google_genai import ChatGoogleGenerativeAI

from langchain_core.messages import SystemMessage, HumanMessage

# specifying a model:
# chat = ChatAnthropic(model="claude-3-opus-20240229")
chat = ChatGoogleGenerativeAI(model="gemini-2.5-pro")
# or:
# chat = ChatOpenAI(model='gpt-4')

# messages:
messages = [
    SystemMessage(content="You're a helpful programming assistant"),
    HumanMessage(content="Write a Python function to calculate factorial")
]
response = chat.invoke(messages)

# %%
print(response.content)
# Out:
# Of course! Here are a few ways to write a Python function to calculate the factorial of a number, from the most common iterative approach to the more advanced recursive and built-in methods.
#
# ### 1. Iterative Approach (Using a Loop)
#
# This is the most straightforward and often the most efficient method for beginners. It uses a simple `for` loop.
#
# **Logic:**
# *   Factorial is not defined for negative numbers, so we check for that first.
# *   The factorial of 0 is 1.
# *   We initialize a result variable to 1.
# *   We loop from 1 up to the given number (`n`), multiplying the result by each number in the sequence.
#
# ```python
# def factorial_iterative(n):
#     """
#     Calculates the factorial of a non-negative integer using a loop.
#
#     Args:
#         n: A non-negative integer.
#
#     Returns:
#         The factorial of n.
#
#     Raises:
#         ValueError: If n is a negative number.
#         TypeError: If n is not an integer.
#     """
#     if not isinstance(n, int):
#         raise TypeError("Input must be an integer.")
#     if n < 0:
#         raise ValueError("Factorial is not defined for negative numbers.")
#
#     if n == 0:
#         return 1
#
#     result = 1
#     # Loop from 1 to n (inclusive)
#     for i in range(1, n + 1):
#         result *= i # same as result = result * i
#
#     return result
#
# # --- Examples ---
# print(f"5! = {factorial_iterative(5)}")    # Output: 5! = 120
# print(f"0! = {factorial_iterative(0)}")    # Output: 0! = 1
# print(f"1! = {factorial_iterative(1)}")    # Output: 1! = 1
#
# try:
#     factorial_iterative(-3)
# except ValueError as e:
#     print(e)  # Output: Factorial is not defined for negative numbers.
# ```
#
# ---
#
# ### 2. Recursive Approach
#
# This method is elegant and a great example of recursion. The function calls itself with a smaller version of the problem until it reaches a "base case".
#
# **Logic:**
# *   **Base Case:** The factorial of 0 is 1. This is the condition that stops the recursion.
# *   **Recursive Step:** For any number `n` greater than 0, the factorial is `n` multiplied by the factorial of `n-1`.
#
# ```python
# def factorial_recursive(n):
#     """
#     Calculates the factorial of a non-negative integer using recursion.
#
#     Args:
#         n: A non-negative integer.
#
#     Returns:
#         The factorial of n.
#     """
#     # Error handling (same as before)
#     if not isinstance(n, int):
#         raise TypeError("Input must be an integer.")
#     if n < 0:
#         raise ValueError("Factorial is not defined for negative numbers.")
#
#     # Base case: when to stop the recursion
#     if n == 0:
#         return 1
#     # Recursive step: call the function with a smaller value
#     else:
#         return n * factorial_recursive(n - 1)
#
# # --- Examples ---
# print(f"5! = {factorial_recursive(5)}")    # Output: 5! = 120
# print(f"0! = {factorial_recursive(0)}")    # Output: 0! = 1
#
# # How it works for factorial_recursive(4):
# # 4 * factorial_recursive(3)
# # 4 * (3 * factorial_recursive(2))
# # 4 * (3 * (2 * factorial_recursive(1)))
# # 4 * (3 * (2 * (1 * factorial_recursive(0))))
# # 4 * (3 * (2 * (1 * 1))) -> 24
# ```
# **Note:** While elegant, recursion in Python can be slower and has a depth limit. For very large numbers, the iterative approach is generally preferred.
#
# ---
#
# ### 3. The Pythonic Way (Using the `math` module)
#
# For real-world applications, you should almost always use the built-in function from Python's standard library. It's highly optimized (written in C) and is the simplest to use.
#
# **Logic:**
# *   Import the `math` module.
# *   Call the `math.factorial()` function. It automatically handles errors for negative numbers and non-integers.
#
# ```python
# import math
#
# def factorial_builtin(n):
#     """
#     Calculates the factorial using the built-in math.factorial function.
#
#     This is the recommended approach for production code.
#     """
#     return math.factorial(n)
#
# # --- Examples ---
# print(f"5! = {factorial_builtin(5)}")      # Output: 5! = 120
# print(f"10! = {factorial_builtin(10)}")    # Output: 10! = 3628800
#
# try:
#     factorial_builtin(-3)
# except ValueError as e:
#     print(e) # Output: factorial() not defined for negative values
#
# try:
#     factorial_builtin(5.5)
# except TypeError as e:
#     print(e) # Output: factorial() only accepts integral values
# ```
#
# ### Summary and Recommendation
#
# | Method | Pros | Cons | Best For |
# | :--- | :--- | :--- | :--- |
# | **Iterative (Loop)** | Easy to understand, efficient, no recursion limit. | Slightly more code than the other methods. | General-purpose programming, interviews. |
# | **Recursive** | Elegant, concise, great for learning recursion. | Slower for large numbers, can hit Python's recursion depth limit. | Educational purposes, problems that are naturally recursive. |
# | **`math.factorial`** | **Fastest**, simplest, handles errors correctly, part of the standard library. | Requires an import statement. | **Almost all real-world applications.** |
