# %% [markdown]
# **How to configure extended thinking (not working)**
#
# pg 36 of the book
# originally using Claude, tried to get it to work with Gemini

# %%
# setting the environment variables, the keys
import sys
import os

sys.path.insert(0, os.path.abspath('..'))

from config import set_environment
# for the keys - as explained early in chapter 2
set_environment()

# %%
from langchain_google_genai import ChatGoogleGenerativeAI
from langchain_core.prompts import ChatPromptTemplate

# %% [markdown]
# Create a template

# %%
# Create a template
template = ChatPromptTemplate.from_messages([
    ("system", "You are an experienced programmer and mathematical analyst."),
    ("user", "{problem}")
])

# Initialize Gemini with extended thinking enabled
chat = ChatGoogleGenerativeAI(
    model="gemini-2.5-flash",
    thinking_config={"includeThoughts": True},
)

# Create and run a chain
chain = template | chat

# Complex algorithmic problem
problem = """
Design an algorithm to find the kth largest element in an unsorted array
with the optimal time complexity. Analyze the time and space complexity
of your solution and explain why it's optimal.
"""

response = chain.invoke({"problem": problem})

print(response.content)

print("\n" + "=" * 30 + "\n")

if response.response_metadata and "thinking" in response.response_metadata:
    print("Model's thinking process:")
    print(response.response_metadata["thinking"])
else:
    print("Model's thinking process not found.")
# Out:
# The problem of finding the kth largest element in an unsorted array is a classic problem in computer science, often referred to as the **selection problem** or finding the **kth order statistic**.
#
# We will design an algorithm based on the **Quickselect** algorithm, which is a modification of the Quicksort algorithm.
#
# ---
#
# ## Algorithm: Quickselect
#
# Quickselect is a selection algorithm that finds the $k$-th smallest (or largest) element in an unsorted array. It works by partitioning the array around a pivot element, similar to Quicksort. However, unlike Quicksort, Quickselect only recurses on one side of the partition, the side that contains the desired element. This significantly reduces its average-case time complexity.
#
# To find the $k$-th largest element, we can find the $(n - k)$-th smallest element (using 0-based indexing), where $n$ is the total number of elements in the array. Let's denote the target index for the $k$-th largest element as `target_idx = n - k`.
#
# ### Core Idea
#
# 1.  **Choose a Pivot:** Select an element from the array as a pivot. A good strategy is to choose a random pivot to ensure good average-case performance and mitigate worst-case scenarios.
# 2.  **Partition:** Rearrange the array such that all elements less than the pivot are to its left, and all elements greater than the pivot are to its right. The pivot element will be in its final sorted position. Let's say its final index is `pivot_final_idx`.
# 3.  **Compare and Recurse:**
#     *   If `pivot_final_idx` is equal to `target_idx`, then the pivot element is the $k$-th largest element, and we return it.
#     *   If `target_idx` is less than `pivot_final_idx`, the $k$-th largest element must be in the left sub-array. We recursively call Quickselect on the left sub-array.
#     *   If `target_idx` is greater than `pivot_final_idx`, the $k$-th largest element must be in the right sub-array. We recursively call Quickselect on the right sub-array.
#
# ### Detailed Steps (Pseudo-code)
#
# Let `arr` be the input array, `n` be its size, and `k` be the desired rank (1-indexed).
#
# ```pseudo
# function findKthLargest(arr, k):
#     n = length(arr)
#     # Convert k-th largest to 0-indexed target for k-th smallest
#     # E.g., for 1st largest (k=1), we want (n-1)-th smallest (last element).
#     # For n-th largest (k=n), we want (n-n)-th smallest (first element).
#     target_idx = n - k
#
#     return quickSelect(arr, 0, n - 1, target_idx)
#
# function quickSelect(arr, left, right, target_idx):
#     if left == right:
#         # Base case: A single element array, it must be the target
#         return arr[left]
#
#     # Choose a random pivot index between left and right
#     # (Using random pivot is crucial for average-case performance)
#     pivot_idx = random_integer(left, right)
#
#     # Partition the array and get the pivot's final position
#     pivot_final_idx = partition(arr, left, right, pivot_idx)
#
#     if target_idx == pivot_final_idx:
#         return arr[target_idx]
#     elif target_idx < pivot_final_idx:
#         # Target is in the left sub-array
#         return quickSelect(arr, left, pivot_final_idx - 1, target_idx)
#     else: # target_idx > pivot_final_idx
#         # Target is in the right sub-array
#         return quickSelect(arr, pivot_final_idx + 1, right, target_idx)
#
# function partition(arr, left, right, pivot_idx):
#     pivot_value = arr[pivot_idx]
#     # Move pivot to the end
#     swap(arr, pivot_idx, right)
#     store_idx = left
#
#     # Iterate through elements from left to right-1
#     # Move all elements smaller than pivot_value to the left of store_idx
#     for i from left to right - 1:
#         if arr[i] < pivot_value:
#             swap(arr, store_idx, i)
#             store_idx = store_idx + 1
#
#     # Move pivot to its final sorted position
#     swap(arr, right, store_idx)
#     return store_idx
#
# function swap(arr, i, j):
#     temp = arr[i]
#     arr[i] = arr[j]
#     arr[j] = temp
# ```
#
# ### Example Walkthrough
#
# Let `arr = [3, 2, 1, 5, 6, 4]` and `k = 2` (find the 2nd largest element).
# `n = 6`. `target_idx = n - k = 6 - 2 = 4`. We are looking for the element at index 4 if the array were sorted.
#
# 1.  `findKthLargest([3, 2, 1, 5, 6, 4], 2)` calls `quickSelect([3, 2, 1, 5, 6, 4], 0, 5, 4)`
# 2.  **Iteration 1:** `left=0`, `right=5`, `target_idx=4`.
#     *   Assume `pivot_idx` is randomly chosen as `2` (value `1`).
#     *   `partition` is called:
#         *   `pivot_value = 1`. `swap(arr, 2, 5)` -> `[3, 2, 4, 5, 6, 1]`
#         *   `store_idx = 0`.
#         *   Loop: `i=0 (3>1)`, `i=1 (2>1)`, `i=2 (4>1)`, `i=3 (5>1)`, `i=4 (6>1)`. No swaps as no elements are smaller than 1.
#         *   `swap(arr, 5, 0)` -> `[1, 2, 4, 5, 6, 3]` (pivot 1 moved to `store_idx=0`)
#         *   `pivot_final_idx = 0`.
#     *   `pivot_final_idx (0)` is not `target_idx (4)`.
#     *   `target_idx (4) > pivot_final_idx (0)`. Recurse on right sub-array: `quickSelect([1, 2, 4, 5, 6, 3], 1, 5, 4)`
# 3.  **Iteration 2:** `left=1`, `right=5`, `target_idx=4`. (Current effective array `[2, 4, 5, 6, 3]`)
#     *   Assume `pivot_idx` is randomly chosen as `3` (original index, value `5`).
#     *   `partition` is called:
#         *   `pivot_value = 5`. `swap(arr, 3, 5)` -> `[1, 2, 4, 3, 6, 5]`
#         *   `store_idx = 1`.
#         *   Loop:
#             *   `i=1 (2<5)`: `swap(arr, 1, 1)` -> `[1, 2, 4, 3, 6, 5]`, `store_idx=2`
#             *   `i=2 (4<5)`: `swap(arr, 2, 2)` -> `[1, 2, 4, 3, 6, 5]`, `store_idx=3`
#             *   `i=3 (3<5)`: `swap(arr, 3, 3)` -> `[1, 2, 4, 3, 6, 5]`, `store_idx=4`
#             *   `i=4 (6>5)`
#         *   `swap(arr, 5, 4)` -> `[1, 2, 4, 3, 5, 6]` (pivot 5 moved to `store_idx=4`)
#         *   `pivot_final_idx = 4`.
#     *   `pivot_final_idx (4)` is equal to `target_idx (4)`.
#     *   Return `arr[4]`, which is `5`.
#
# The 2nd largest element is `5`. This is correct.
#
# ---
#
# ## Complexity Analysis
#
# ### Time Complexity
#
# 1.  **Average Case: O(n)**
#     *   In the average case, each partition step divides the array roughly in half.
#     *   The work done at each level of recursion is proportional to the size of the current sub-array.
#     *   The recurrence relation is approximately `T(n) = T(n/2) + O(n)`.
#     *   This recurrence solves to `O(n)`. The sum of work at each level `n + n/2 + n/4 + ... + 1` is approximately `2n`, hence `O(n)`.
#     *   The use of a random pivot is crucial for achieving this average-case performance. It prevents consistently choosing bad pivots.
#
# 2.  **Worst Case: O(n^2)**
#     *   The worst case occurs if the pivot selection consistently chooses the smallest or largest element in the sub-array.
#     *   In this scenario, the partition effectively reduces the problem size by only one element at each step.
#     *   The recurrence relation becomes `T(n) = T(n-1) + O(n)`.
#     *   This recurrence solves to `O(n^2)`.
#     *   For example, if the array is already sorted and we always pick the first element as a pivot, this worst-case behavior will occur. Randomizing the pivot helps to make this worst case extremely unlikely in practice.
#
# 3.  **Expected Time Complexity: O(n)**
#     *   For a randomized algorithm like Quickselect, we analyze its *expected* time complexity. Even though the worst-case is `O(n^2)`, the probability of hitting it is astronomically small. The expected time complexity for randomized Quickselect is `O(n)`.
#
# ### Space Complexity
#
# 1.  **Average Case: O(log n)**
#     *   This is due to the recursion stack depth. In the average case, the array is split roughly in half at each step, leading to a logarithmic number of recursive calls.
#
# 2.  **Worst Case: O(n)**
#     *   Similar to the worst-case time complexity, if the pivot selection consistently leads to highly unbalanced partitions (e.g., reducing the problem size by only one element), the recursion depth can go up to `n`, leading to `O(n)` space for the call stack.
#     *   This can be optimized to `O(1)` auxiliary space by implementing Quickselect iteratively (using a loop instead of recursion) or by using tail-call optimization if the language supports it for the last recursive call.
#
# ---
#
# ## Why is it Optimal?
#
# The Quickselect algorithm (with randomized pivot selection, or with a deterministic Median-of-Medians pivot selection) achieves an **average-case time complexity of O(n)**.
#
# **Lower Bound for Comparison-Based Selection:**
# To find the $k$-th largest element in an unsorted array using only comparisons, you must, in the worst case, examine a significant fraction of the elements. For example, to find the minimum element (1st smallest), you generally need to look at all `n` elements to ensure that the one you picked is indeed the minimum. If you skip an element, it *could* be the true minimum.
#
# More formally, it can be proven that any comparison-based algorithm for finding the $k$-th order statistic requires at least `Ω(n)` comparisons in the worst case. This is because, without examining an element, you cannot definitively rule it out as the $k$-th largest, nor can you correctly determine the relative order of other elements if that unexamined element was the true $k$-th largest.
#
# Since Quickselect achieves `O(n)` time complexity (on average, or deterministically with a more complex pivot strategy), it is **asymptotically optimal** for comparison-based selection algorithms. No comparison-based algorithm can do better than `O(n)` in the worst case.
#
# ### Comparison with other approaches:
#
# *   **Sorting the array:** `O(n log n)` time complexity (e.g., Merge Sort, Heap Sort). This is slower than Quickselect's `O(n)` average case because it does more work than necessary (it sorts *all* elements, not just finds one).
# *   **Using a Min-Heap of size k:** `O(n log k)` time complexity. This is `O(n log n)` in the worst case (when `k` is close to `n`), but better if `k` is very small. Quickselect is `O(n)` regardless of `k`'s value (on average).
#
# Therefore, Quickselect is generally the preferred algorithm for this problem due to its optimal average-case time complexity.
#
# ==============================
#
# Model's thinking process not found.
