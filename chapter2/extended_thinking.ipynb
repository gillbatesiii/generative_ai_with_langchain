# %% [markdown]
# **How to configure extended thinking (not working)**
#
# pg 36 of the book
# originally using Claude, tried to get it to work with Gemini
# maybe "thinking_config" is configured wrong

# %%
# setting the environment variables, the keys
import sys
import os

sys.path.insert(0, os.path.abspath('..'))

from config import set_environment
# for the keys - as explained early in chapter 2
set_environment()

# %%
from langchain_google_genai import ChatGoogleGenerativeAI
from langchain_core.prompts import ChatPromptTemplate

# %% [markdown]
# Create a template

# %%
# Create a template
template = ChatPromptTemplate.from_messages([
    ("system", "You are an experienced programmer and mathematical analyst."),
    ("user", "{problem}")
])

# Initialize Gemini with extended thinking enabled
chat = ChatGoogleGenerativeAI(
    model="gemini-1.5-flash-latest",
    thinking_config={"includeThoughts": True},
)

# Create and run a chain
chain = template | chat

# Complex algorithmic problem
problem = """
Design an algorithm to find the kth largest element in an unsorted array
with the optimal time complexity. Analyze the time and space complexity
of your solution and explain why it's optimal.
"""

response = chain.invoke({"problem": problem})

print(response.content)

print("\n" + "=" * 30 + "\n")

if response.response_metadata and "thinking" in response.response_metadata:
    print("Model's thinking process:")
    print(response.response_metadata["thinking"])
else:
    print("Model's thinking process not found.")
# Out:
# The optimal algorithm for finding the kth largest element in an unsorted array is based on the QuickSelect algorithm, a variation of the QuickSort algorithm.  It achieves an average time complexity of O(n), which is optimal because you must examine at least n elements in the worst case to determine the kth largest.
#
# **Algorithm (QuickSelect):**
#
# 1. **Partition:**  Choose a pivot element from the array (strategies for pivot selection are discussed below).  Partition the array around the pivot such that all elements smaller than the pivot are placed before it, and all elements larger than the pivot are placed after it.  Elements equal to the pivot can be placed on either side.
#
# 2. **Index Calculation:** Determine the index of the pivot after partitioning. Let's call this index `pivotIndex`.
#
# 3. **Recursive Call (if necessary):**
#    - If `pivotIndex == n - k` (where `n` is the array size), the pivot is the kth largest element. Return the pivot.
# ...
